# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
# %pip install umap-learn
from umap import umap_ 
# %matplotlib inline
sns.set(style='white', context='poster', rc={'figure.figsize':(14,10)})
np.random.seed(44)
data = np.random.rand(700, 4)
fit = umap_.UMAP()
# %time u = fit.fit_transform(data)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# CPU times: total: 16.4 s
# Wall time: 13.2 s

# %%
from re import U
plt.scatter(u[:,0], u[:,1], c=data)
plt.title('UMAP embedding of random colours')
plt.show()
# This code generates a 2D UMAP embedding of random colors and visualizes it.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from umap import umap_
# %matplotlib inline
sns.set(style='white', context='poster', rc={'figure.figsize':(14,10)})
np.random.seed(44)
data = np.random.rand(700, 4)
fit = umap_.UMAP()
# %time u = fit.fit_transform(data)
# Out:
# CPU times: total: 4.02 s
# Wall time: 550 ms

# %%
plt.scatter(u[:,0], u[:,1], c=data)
plt.title('UMAP embedding of random colours')
plt.show()
# This code generates a 2D UMAP embedding of random colors and visualizes it.

# %%
import numpy as np
from umap import UMAP  # Changed this import
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

digits = load_digits()
data = digits.data
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Apply UMAP
reducer = UMAP()  # Changed this line
embedding = reducer.fit_transform(data)
plt.scatter(embedding[:, 0], embedding[:, 1], c=digits.target, cmap='Spectral', s=5)
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[28], line 2
#       1 import numpy as np
# ----> 2 from umap import UMAP  # Changed this import
#       3 from sklearn.datasets import load_digits
#       4 from sklearn.preprocessing import StandardScaler
#
# ImportError: cannot import name 'UMAP' from 'umap' (C:\Users\KIIT\AppData\Roaming\Python\Python312\site-packages\umap\__init__.py)
